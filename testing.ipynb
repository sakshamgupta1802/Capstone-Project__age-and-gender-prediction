# %% [markdown]
# # Evaluating the  data

# %%
# Here I test our model on five testing image.

# %%
# 0 corresponds to male, 1 corresponds to female.
rand_number = random.randint(0,len(X_test))
img=X_test[rand_number]
plt.imshow(img)
g = y_test[rand_number]
h = get_gender(z_test[rand_number]))

print("               (",g,",",h,")")
# Out:
#                ( male , 61 )

# %%
# 0 corresponds to male, 1 corresponds to female.
rand_number = random.randint(0,len(X_test))
img=X_test[rand_number]
plt.imshow(img)
g = y_test[rand_number]
h = get_gender(z_test[rand_number]))

print("               (",g,",",h,")")
# Out:
#                ( male , 28 )

# %%
# 0 corresponds to male, 1 corresponds to female.
rand_number = random.randint(0,len(X_test))
img=X_test[rand_number]
plt.imshow(img)
g = y_test[rand_number]
h = get_gender(z_test[rand_number]))

print("               (",g,",",h,")")
# Out:
#                ( male , 35 )

# %%
# 0 corresponds to male, 1 corresponds to female.
rand_number = random.randint(0,len(X_test))
img=X_test[rand_number]
plt.imshow(img)
g = y_test[rand_number]
h = get_gender(z_test[rand_number]))

print("               (",g,",",h,")")
# Out:
#                ( female , 36 )

# %%
# 0 corresponds to male, 1 corresponds to female.
rand_number = random.randint(0,len(X_test))
img=X_test[rand_number]
plt.imshow(img)
g = y_test[rand_number]
h = get_gender(z_test[rand_number]))

print("               (",g,",",h,")")
# Out:
#                ( female , 30 )
